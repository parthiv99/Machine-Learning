# %% [markdown]
# #K-Means clustering
#
# > Parthiv Desai
#
# > CPSC-483-03

# %% [markdown]
# #Importing the libraries

# %%
import numpy as np  #Numpy is widely used library for handling number
import matplotlib.pyplot as plt #Provides a library for data visualization for plotting graphs
import pandas as pd  #Used for data manipulation

# %% [markdown]
# #Importing the dataset

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Mall_Customers_Kmeans.csv") #Pull the Data.csv file from CSV into a variable.
X = dataset.iloc[:,[3,4]].values #Indexing all the values till the last row.

# %% [markdown]
# #Using the elbow method to find the optimal number of clusters

# %%
from sklearn.cluster import KMeans #Importing Kmeans from sklearn library
wcss = [] #Elbow method helps in finding out the best numbers of clusters
for i in range(1,11): #For loop will fit the kmeans algorithm
  kmeans= KMeans(n_clusters = i, init = 'k-means++',random_state = 42) #The random state is set at 42. i is between 1-10, it also find the final clusters
  kmeans.fit(X) #Fits the kmeans and compute the sum of all cluster of squares and join them in the wcss list.
  wcss.append(kmeans.inertia_) #Sum of squared distances of all the samples.
plt.plot(range(1, 11), wcss) #Plotting from the range 1-11
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# #Training the K-means model on the dataset

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0) #Determine the cluster number
y_kmeans = kmeans.fit_predict(X) #Fitting and predicting to the X dataset.

# %% [markdown]
# #Visualising the clusters

# %%
plt.scatter(X[y_kmeans == 0,0], X[y_kmeans== 0,1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans==1, 1], s=100, c='blue', label ='Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans==2, 1], s=100, c='green', label ='Cluster 3')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans==3, 1], s=100, c='cyan', label ='Cluster 4')
plt.scatter(X[y_kmeans == 4, 0], X[y_kmeans==4, 1], s=100, c='magenta', label ='Cluster 5')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='yellow', label = 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income(k$)')
plt.ylabel('Spending Score(1-100')
plt.show()
